# %%
import gymnasium as gym
import random

# importing functions from utils
from helpers.loggers import logger
import helpers.utils as utils
import helpers.agents as agents

# To allow auto reload to this notebook after modifying any external file imported
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
env = gym.make("Taxi-v3", render_mode="ansi")

# seed random generators and the environment to replicate results
utils.seed(42, env)

# %%
agent = agents.RandomAgent(env)

# %% [markdown]
# Using a single episod

# %%
# defining and keeping track of values
penalties = agents.Value(data=0, label='penalties')
total_rewards = agents.Value(data=0, label='penalties')
epochs = agents.Value(data=0, label='epochs')

# both terminated, truncated are returned on every step
terminated, truncated = False, False

# reset the environment if you run this block
obs, info = env.reset()
utils.show_state(0, env, obs, 0)

# training loop
while not ((terminated) or (truncated)):
    # get the action value
    action = agent.get_action()

    # take a step towards the solution
    obs, reward, terminated, truncated, info = env.step(action)

    # keep track of values
    total_rewards += reward

    if reward == -10:
        penalties += reward
    
    epochs += 1

    # show current state
    # utils.show_state(epochs, env, obs, reward)
    # print(reward, total_rewards, penalties, terminated, truncated, epochs.data)
    
    
print("Epochs taken: {}".format(epochs.data))
print("Penalties incurred: {}".format(penalties.data))

utils.show_state(epochs.data, env, obs, total_rewards.data)
# Out:
# Step 0: [0, 4, 2, 0], Reward: 0
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# Epochs taken: 200
# Penalties incurred: -510
# Step 200: [2, 0, 4, 0], Reward: -659
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %% [markdown]
# Using multiple episods

# %%
n_episodes = agents.Value(data=10000, label='n_Episodes')

# For plotting metrics
epochs_per_episode = []
penalties_per_episode = []


for episode in range(n_episodes.data):
    # defining and keeping track of values
    penalties = agents.Value(data=0, label='penalties')
    total_rewards = agents.Value(data=0, label='penalties')    
    epochs = agents.Value(data=0, label='epochs')
    
    # both terminated, truncated are returned on every step
    terminated, truncated = False, False
    
    # reset the environment
    obs, info = env.reset()

    # training loop
    while not ((terminated) or (truncated)):
        # get the action value
        action = agent.get_action()

        # take a step towards the solution
        obs, reward, terminated, truncated, info = env.step(action)
    
        # keep track of values
        total_rewards += reward
        if reward == -10:
            penalties += reward
        
        epochs += 1
        # logger.info(f"Episode {_ + 1}: Length = {epochs.data}, Terminated = {terminated}, Truncated = {truncated}")

    
    epochs_per_episode.append(epochs.data)
    penalties_per_episode.append(penalties.data)

# %%
utils.plot_learning(list(range(1, n_episodes.data + 1)), epochs_per_episode, legend_title='Epochs per Episod', ylabel='Epochs')
utils.plot_learning(list(range(1, n_episodes.data + 1)), penalties_per_episode, legend_title='Penalities per Episod', ylabel='Penalities')

# %% [markdown]
# #### Let's test visually!

# %%
agent.test()
# Out:
# Step 0: [2, 1, 2, 0], Reward: 0
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# Step 1: [2, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 2: [2, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 3: [2, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 4: [2, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 5: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 6: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 7: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 8: [1, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 9: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 10: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 11: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 12: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 13: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 14: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 15: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 16: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 17: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 18: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 19: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 20: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 21: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 22: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 23: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 24: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 25: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 26: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 27: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 28: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 29: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 30: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 31: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 32: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 33: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 34: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 35: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 36: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 37: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 38: [1, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 39: [1, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 40: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 41: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 42: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 43: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 44: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 45: [1, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 46: [2, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 47: [2, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 48: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 49: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 50: [3, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 51: [3, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 52: [3, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 53: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 54: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 55: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 56: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 57: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 58: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 59: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 60: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 61: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 62: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 63: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 64: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 65: [2, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 66: [2, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 67: [2, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 68: [2, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 69: [2, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 70: [2, 4, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 71: [3, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 72: [2, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 73: [2, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 74: [3, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 75: [2, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 76: [2, 3, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 77: [1, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 78: [1, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 79: [1, 4, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 80: [0, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 81: [0, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 82: [0, 3, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 83: [0, 3, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 84: [0, 3, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 85: [0, 3, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 86: [0, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 87: [1, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 88: [0, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 89: [0, 4, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 90: [0, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 91: [0, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 92: [0, 4, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 93: [1, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 94: [0, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 95: [1, 4, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 96: [1, 3, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 97: [1, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 98: [2, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 99: [1, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 100: [2, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 101: [1, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 102: [2, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 103: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 104: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 105: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 106: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 107: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 108: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 109: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 110: [2, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 111: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 112: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 113: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 114: [3, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 115: [3, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 116: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 117: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 118: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 119: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 120: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 121: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 122: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 123: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 124: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 125: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 126: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 127: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 128: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 129: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 130: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 131: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 132: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 133: [4, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 134: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 135: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 136: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 137: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 138: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 139: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 140: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 141: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 142: [2, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 143: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 144: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 145: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 146: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 147: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 148: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 149: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 150: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 151: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 152: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 153: [3, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 154: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 155: [3, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 156: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 157: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 158: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 159: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 160: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 161: [4, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 162: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 163: [4, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 164: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 165: [4, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 166: [3, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 167: [3, 2, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 168: [2, 2, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 169: [2, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 170: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 171: [1, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 172: [1, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 173: [1, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 174: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 175: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 176: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 177: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 178: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 179: [0, 1, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 180: [1, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 181: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 182: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 183: [0, 1, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 184: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 185: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 186: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 187: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 188: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 189: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 190: [0, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 191: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 192: [1, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 193: [0, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 194: [1, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 195: [1, 0, 2, 0], Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 196: [1, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 197: [1, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 198: [1, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 199: [1, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 200: [1, 0, 2, 0], Reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)

# %% [markdown]
# As expected, the random agent entirely failed, and loop truncated after maximum epoch iterations.
